# %% [markdown]
# # Optimization Results Analysis

# %% [markdown]
# ## Genetic Algorithms

# %%
import pandas as pd
ga_results = pd.read_csv("results.csv")

# %%
ga_results.columns = ["filename", "population_size", "n_generations", "mutate_mode", "crossover_mode", "best_score", "fittest", "time"]

# %%
ga_results_b = ga_results[ga_results["filename"] == "data/b_read_on.in"].reset_index()
ga_results_c = ga_results[ga_results["filename"] == "data/c_incunabula.in"].reset_index()
ga_results_d = ga_results[ga_results["filename"] == "data/d_tough_choices.in"].reset_index()
ga_results_e = ga_results[ga_results["filename"] == "data/e_so_many_books.in"].reset_index()
ga_results_f = ga_results[ga_results["filename"] == "data/f_libraries_of_the_world.in"].reset_index()

# %%
ga_fittest = pd.DataFrame(columns=ga_results.columns)

# %% [markdown]
# ### b_read_on.in

# %%
b_fittest = ga_results_b.iloc[ga_results_b['best_score'].idxmax()]
ga_fittest.loc[len(ga_fittest)] = b_fittest

# %% [markdown]
# ### c_incunabula.in

# %%
c_fittest = ga_results_c.iloc[ga_results_c['best_score'].idxmax()]
ga_fittest.loc[len(ga_fittest)] = c_fittest

# %% [markdown]
# ### d_tough_choices.in

# %%
d_fittest = ga_results_d.iloc[ga_results_d['best_score'].idxmax()]
ga_fittest.loc[len(ga_fittest)] = d_fittest

# %% [markdown]
# ### e_so_many_books.in

# %%
e_fittest = ga_results_e.iloc[ga_results_e['best_score'].idxmax()]
ga_fittest.loc[len(ga_fittest)] = e_fittest

# %% [markdown]
# ### f_libraries_of_the_world.in

# %%
f_fittest = ga_results_f.iloc[ga_results_f['best_score'].idxmax()]
ga_fittest.loc[len(ga_fittest)] = f_fittest

# %% [markdown]
# ## Fittest individuals

# %%
ga_fittest['time_min'] = ga_fittest['time']/60
ga_fittest = ga_fittest.drop(axis="columns",columns=["time"])

# %%
ga_fittest
# Out:
#                            filename population_size n_generations mutate_mode  \
# 0                 data/b_read_on.in              20      (10, 10)        swap
# 1              data/c_incunabula.in              20       (10, 1)    addition
# 2           data/d_tough_choices.in              20       (10, 1)    addition
# 3           data/e_so_many_books.in              20       (10, 9)    deletion
# 4  data/f_libraries_of_the_world.in              20       (10, 6)    deletion
#
#   crossover_mode best_score   time_min
# 0         random    4770900   7.174509
# 1            mid    1014099   1.196788
# 2         random    4362930  17.994747
# 3         random    1258925   2.669957
# 4            mid    1831208   1.341743

# %% [markdown]
# ## Fittest: generations log

# %%
import matplotlib.pyplot as plt

# %%
b_score_log = [[4210900, 4452700, 4354700, 4211900, 4246800, 4256500, 4214100, 4271700, 4228700, 4134000, 4180000, 3956800, 4584300, 4306100, 4249400, 3996600, 4351000, 4116900, 4069600, 4238600, 4143200, 4491200, 4185900, 3892600, 4420300], [4210900, 4452700, 4354700, 4211900, 4246800, 4256500, 4214100, 4271700, 4228700, 4134000, 4180000, 4157400, 4584300, 4306100, 4249400, 3996600, 4351000, 4116900, 4069600, 4238600, 4143200, 4491200, 4185900, 4030200, 4420300], [4210900, 4452700, 4354700, 4211900, 4246800, 4256500, 4214100, 4271700, 4228700, 4134000, 4180000, 4157400, 4584300, 4306100, 4249400, 4237300, 4351000, 4116900, 4069600, 4238600, 4143200, 4491200, 4185900, 3829000, 4420300], [4210900, 4452700, 4354700, 4211900, 4246800, 4256500, 4214100, 4271700, 4228700, 4134000, 4180000, 4157400, 4584300, 4306100, 4249400, 4237300, 4351000, 4116900, 4069600, 4238600, 4143200, 4491200, 4185900, 4088000, 4420300], [4210900, 4452700, 4354700, 4211900, 4246800, 4256500, 4214100, 4271700, 4228700, 4134000, 4180000, 4157400, 4584300, 4306100, 4249400, 4237300, 4351000, 4116900, 4122100, 4238600, 4143200, 4491200, 4185900, 4103600, 4420300], [4210900, 4452700, 4354700, 4211900, 4246800, 4256500, 4214100, 4271700, 4228700, 4134000, 4180000, 4157400, 4584300, 4306100, 4249400, 4237300, 4351000, 4219300, 4122100, 4238600, 4143200, 4491200, 4185900, 4294700, 4420300], [4210900, 4452700, 4354700, 4211900, 4246800, 4256500, 4214100, 4271700, 4228700, 4088200, 4180000, 4157400, 4584300, 4306100, 4249400, 4237300, 4351000, 4219300, 4148500, 4238600, 4143200, 4491200, 4185900, 4294700, 4420300], [4210900, 4452700, 4354700, 4211900, 4246800, 4256500, 4214100, 4271700, 4228700, 4299600, 4180000, 4157400, 4584300, 4306100, 4249400, 4237300, 4351000, 4219300, 4148500, 4238600, 4096100, 4491200, 4185900, 4294700, 4420300], [4210900, 4452700, 4354700, 4211900, 4246800, 4256500, 4214100, 4271700, 4228700, 4299600, 4180000, 4157400, 4584300, 4306100, 4249400, 4237300, 4351000, 4219300, 4491200, 4238600, 4491200, 4491200, 4185900, 4294700, 4420300], [4210900, 4452700, 4354700, 4211900, 4246800, 4256500, 4214100, 4271700, 4228700, 4299600, 4180000, 4486800, 4584300, 4306100, 4249400, 4237300, 4351000, 4219300, 
[1100784, 1023414, 904772, 923950, 1092017, 1029425, 1132056, 1050501, 1001449, 1192959, 952585, 1065661, 882912, 1155257, 
1035594, 1150178, 969043, 1183916, 1090731, 1011766, 941604, 1177327, 914093, 1081904, 1072773], [1100784, 1023414, 904772, 923950, 1092017, 1029425, 1132056, 1050501, 1001449, 1192959, 952585, 1065661, 
1049495, 1155257, 1035594, 1150178, 969043, 1183916, 1090731, 1011766, 941604, 1177327, 914093, 1081904, 1072773], [1100784, 1023414, 1084516, 923950, 1092017, 1029425, 1132056, 1050501, 1001449, 1192959, 952585, 1065661, 1049495, 1155257, 1035594, 1150178, 969043, 1183916, 1090731, 1011766, 941604, 1177327, 914093, 1081904, 1072773], [1100784, 1023414, 1084516, 954521, 1092017, 1029425, 1132056, 1050501, 1001449, 1192959, 952585, 1065661, 1049495, 1155257, 1035594, 1150178, 969043, 1183916, 1090731, 1011766, 941604, 1177327, 984983, 1081904, 1072773], [1100784, 1023414, 1084516, 954521, 1092017, 1029425, 1132056, 1050501, 1001449, 1192959, 970415, 1065661, 1049495, 1155257, 1035594, 1150178, 969043, 1183916, 1090731, 1011766, 1100845, 1177327, 984983, 1081904, 1072773], [1100784, 1023414, 1084516, 1088574, 1092017, 1029425, 1132056, 1050501, 1001449, 1192959, 970415, 1065661, 1049495, 1155257, 1035594, 1150178, 1105479, 1183916, 1090731, 1011766, 1100845, 1177327, 984983, 1081904, 1072773]]
f_score_log = [[875870, 474960, 709214, 591603, 908373, 387054, 872163, 918524, 978501, 609604, 1026019, 1615052, 751098, 597973, 561232, 1240532, 1028638, 702851, 445641, 662727], [875870, 474960, 709214, 591603, 908373, 877938, 872163, 918524, 978501, 609604, 1026019, 1615052, 751098, 597973, 561232, 1240532, 1028638, 702851, 810817, 662727], [875870, 727430, 709214, 591603, 908373, 877938, 872163, 918524, 978501, 609604, 1026019, 1615052, 751098, 597973, 374975, 1240532, 1028638, 702851, 810817, 662727], [875870, 727430, 709214, 591603, 908373, 877938, 872163, 918524, 978501, 609604, 1026019, 1615052, 751098, 597973, 613610, 1240532, 1028638, 702851, 810817, 662727], [875870, 727430, 709214, 1032054, 908373, 877938, 872163, 918524, 978501, 609604, 1026019, 1615052, 751098, 1394464, 613610, 1240532, 1028638, 702851, 810817, 662727], [875870, 727430, 709214, 1032054, 908373, 877938, 872163, 918524, 978501, 1667328, 1026019, 1615052, 751098, 1394464, 744853, 1240532, 1028638, 702851, 810817, 662727], [875870, 727430, 709214, 1032054, 908373, 877938, 872163, 918524, 978501, 1667328, 1026019, 1615052, 751098, 1394464, 744853, 1240532, 1028638, 1831208, 810817, 816906], [875870, 934668, 936803, 1032054, 908373, 877938, 872163, 918524, 978501, 1667328, 1026019, 1615052, 751098, 1394464, 744853, 1240532, 1028638, 1831208, 810817, 816906], [875870, 934668, 936803, 1032054, 908373, 877938, 872163, 918524, 978501, 1667328, 1026019, 1615052, 723255, 1394464, 969904, 1240532, 1028638, 1831208, 810817, 816906], [875870, 934668, 936803, 1032054, 908373, 877938, 872163, 918524, 978501, 1667328, 1026019, 1615052, 723255, 1394464, 969904, 1240532, 1028638, 1831208, 810817, 816906], [875870, 934668, 936803, 1032054, 908373, 877938, 872163, 918524, 978501, 1667328, 1026019, 1615052, 1132652, 1394464, 969904, 1240532, 1028638, 1831208, 1121438, 816906]]

# %%
# Visualizing: creating figure with 10 subplots
file_score_log = f_score_log
e_score_log = e_score_log[:10]
title = f"Population evoluion: f_libraries_in_the_world.in"
fig_rows = 2
fig_cols = 5

subplots_indexes = []
for i in range(fig_rows):
    for j in range(fig_cols):    
        subplots_indexes.append((i, j))

fig, axs = plt.subplots(nrows=fig_rows, ncols=fig_cols, sharex=True, sharey=True, figsize=(12, 7))

for generation, (i, j) in zip(range(len(file_score_log)), subplots_indexes):
    x = [individual for individual in range(1, len(file_score_log[generation])+1)]
    y = file_score_log[generation]
    axs[i, j].plot(x, y, '-ok', markersize=3)
    axs[i, j].set_title(f"Gen {generation}")

fig.text(0.5, 0.04, 'Individuals', ha='center')
fig.text(0.04, 0.5, 'Scores', va='center', rotation='vertical')
fig.text(0.3, 0.95, title, size=14)

plt.subplots_adjust(left=0.08,
                   bottom=0.1,  
                    top=0.89,
                    wspace=0.1,
                    hspace=0.2)
plt.show()
